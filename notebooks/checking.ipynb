# %%
import os

print(os.listdir("../models"))
print(os.listdir("../graphs"))
print(os.listdir("../reports"))
# Out:
# ['best_densenet121.keras', 'best_efficientnetb0.keras', 'best_inceptionv3.keras', 'best_mobilenetv2.keras', 'best_resnet50.keras', 'final_densenet121.keras', 'final_inceptionv3.keras', 'final_mobilenetv2.keras']
# ['densenet121_accuracy.png', 'densenet121_confusion_matrix.png', 'densenet121_loss.png', 'final_model_comparison.png', 'inceptionv3_accuracy.png', 'inceptionv3_confusion_matrix.png', 'inceptionv3_loss.png', 'mobilenetv2_accuracy.png', 'mobilenetv2_confusion_matrix.png', 'mobilenetv2_loss.png', 'resnet50_accuracy.png', 'resnet50_confusion_matrix.png', 'resnet50_loss.png']
# ['densenet121_classification_report.txt', 'densenet121_training_history.csv', 'final_performance_summary.csv', 'inceptionv3_classification_report.txt', 'inceptionv3_training_history.csv', 'mobilenetv2_classification_report.txt', 'mobilenetv2_training_history.csv', 'model_comparison.csv', 'resnet50_classification_report.txt', 'resnet50_training_history.csv']
